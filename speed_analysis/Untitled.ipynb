# %%
import tweepy #https://github.com/tweepy/tweepy
import csv
import configparser

#Twitter API credentials
consumer_key = ""
consumer_secret = ""
access_key = ""
access_secret = ""


def get_all_tweets(screen_name):
    #Twitter only allows access to a users most recent 3240 tweets with this method
    
    parser = configparser.ConfigParser()
    parser.read("../../tokens.txt")

    auth = tweepy.OAuthHandler(parser.get("Twitter", "tw_ApiKey"), parser.get("Twitter", "tw_ApiKeySecret"))
    auth.set_access_token(parser.get("Twitter", "tw_AccessToken"), parser.get("Twitter", "tw_AccessTokenSecret"))
    api = tweepy.API(auth, wait_on_rate_limit=True)
    
    #initialize a list to hold all the tweepy Tweets
    alltweets = []  
    
    #make initial request for most recent tweets (200 is the maximum allowed count)
    new_tweets = api.user_timeline(screen_name = screen_name,count=200)
    
    #save most recent tweets
    alltweets.extend(new_tweets)
    
    #save the id of the oldest tweet less one
    oldest = alltweets[-1].id - 1
    
    #keep grabbing tweets until there are no tweets left to grab
    while len(new_tweets) > 0:
        print(f"getting tweets before {oldest}")
        
        #all subsiquent requests use the max_id param to prevent duplicates
        new_tweets = api.user_timeline(screen_name = screen_name,count=200,max_id=oldest)
        
        #save most recent tweets
        alltweets.extend(new_tweets)
        
        #update the id of the oldest tweet less one
        oldest = alltweets[-1].id - 1
        
        print(f"...{len(alltweets)} tweets downloaded so far")
    
    #transform the tweepy tweets into a 2D array that will populate the csv 
    outtweets = [[tweet.id_str, tweet.created_at, tweet.text] for tweet in alltweets]
    
    #write the csv  
    with open(f'new_{screen_name}_tweets.csv', 'w') as f:
        writer = csv.writer(f)
        writer.writerow(["id","created_at","text"])
        writer.writerows(outtweets)
    
    pass


if __name__ == '__main__':
	#pass in the username of the account you want to download
	get_all_tweets("netanyahu")
# Out:
# getting tweets before 1491812747071340546
# ...400 tweets downloaded so far
# getting tweets before 1473377714425978886
# ...600 tweets downloaded so far
# getting tweets before 1457335533642911747
# ...800 tweets downloaded so far
# getting tweets before 1443907362499272707
# ...1000 tweets downloaded so far
# getting tweets before 1419723058840023040
# ...1200 tweets downloaded so far
# getting tweets before 1404394273857019905
# ...1400 tweets downloaded so far
# getting tweets before 1393212958482866183
# ...1600 tweets downloaded so far
# getting tweets before 1377977251367694339
# ...1800 tweets downloaded so far
# getting tweets before 1369323080666013700
# ...2000 tweets downloaded so far
# getting tweets before 1361917556521598976
# ...2200 tweets downloaded so far
# getting tweets before 1350745787400118272
# ...2400 tweets downloaded so far
# getting tweets before 1340681621041758207
# ...2600 tweets downloaded so far
# getting tweets before 1329695360135147520
# ...2800 tweets downloaded so far
# getting tweets before 1317828307405230079
# ...2999 tweets downloaded so far
# getting tweets before 1303728960967237632
# ...3199 tweets downloaded so far
# getting tweets before 1293482870506491904
# ...3249 tweets downloaded so far
# getting tweets before 1291026469783838719
# ...3249 tweets downloaded so far
